# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity

# %%
data = {
    'User': ['U1','U1','U2','U2','U3','U3'],
    'Item': ['I1','I2','I1','I3','I2','I3'],
    'Rating': [5,4,4,5,3,4]
}
df = pd.DataFrame(data)

# %%
matrix = df.pivot_table(index='User', columns='Item', values='Rating').fillna(0)
print(matrix)
# Out:
# Item   I1   I2   I3
# User
# U1    5.0  4.0  0.0
# U2    4.0  0.0  5.0
# U3    0.0  3.0  4.0

# %%
similarity = cosine_similarity(matrix.T)
similarity_df = pd.DataFrame(similarity, index=matrix.columns, columns=matrix.columns)
print(similarity_df)
# Out:
# Item        I1        I2        I3
# Item
# I1    1.000000  0.624695  0.487805
# I2    0.624695  1.000000  0.374817
# I3    0.487805  0.374817  1.000000

# %%
def recommend(item):
    return similarity_df[item].sort_values(ascending=False)

# %%
print(recommend('I1'))
# Out:
# Item
# I1    1.000000
# I2    0.624695
# I3    0.487805
# Name: I1, dtype: float64
